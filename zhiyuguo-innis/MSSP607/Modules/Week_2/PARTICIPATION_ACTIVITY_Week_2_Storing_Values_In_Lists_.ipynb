# %% [markdown]
# <a href="https://colab.research.google.com/github/zhiyuguo-innis/MSSP607/blob/main/zhiyuguo-innis/MSSP607/Modules/Week_2/PARTICIPATION_ACTIVITY_Week_2_Storing_Values_In_Lists_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
spam = [2, 4, 6, 8, 10]

# Assign 'hello' as the third value (index 2)
spam[2] = 'hello'

print(spam)
# Out:
# [2, 4, 'hello', 8, 10]

# %%
letters = ['a', 'b', 'c', 'd']

# int('3' * 2) = int('33') = 33
# 33 // 11 = 3, so letters[3] is 'd'
print(letters[int(int('3' * 2) // 11)])

# -1 means the last item in the list, so letters[-1] is 'd'
print(letters[-1])

# [:2] means starting from the beginning up to, but not including, index 2
# Therefore, it includes index 0 and index 1: ['a', 'b']
print(letters[:2])
# Out:
# d
# d
# ['a', 'b']

# %%
# Create a list
my_list = [1, 2, 3, 4]

# Convert a list to a tuple
my_tuple = tuple(my_list)
print(my_tuple)

# Convert a tuple back to a list
new_list = list(my_tuple)
print(new_list)
# Out:
# (1, 2, 3, 4)
# [1, 2, 3, 4]

# %%
def comma_code(spam):
    if len(spam) == 0:
        return ''
    elif len(spam) == 1:
        return spam[0]
    elif len(spam) == 2:
        return spam[0] + ' and ' + spam[1]
    else:
        return ', '.join(spam[:-1]) + ', and ' + spam[-1]


spam = ['apples', 'bananas', 'tofu', 'cats']

print(comma_code(spam))
# Out:
# apples, bananas, tofu, and cats
